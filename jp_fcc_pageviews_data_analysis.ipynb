# %% [markdown]
# <p style=text-align:center;> FCC Pageviews Data Analysis </p>
# <p style=text-align:center;> By John Pierre </p>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

df = pd.read_csv('fcc-forum-pageviews.csv', parse_dates=['date'], index_col='date')

df.head()
# Out:
#             value
# date
# 2016-05-09   1201
# 2016-05-10   2329
# 2016-05-11   1716
# 2016-05-12  10539
# 2016-05-13   6933

# %%
lower_bound = df['value'].quantile(0.025) # Bottom 2.5%
upper_bound = df['value'].quantile(0.975) # Top 2.5%

df = df[(df['value'] >= lower_bound) & (df['value'] <= upper_bound)]

# %%
def draw_line_plot():
    # Set figure size
    fig, ax = plt.subplots(figsize=(12, 6))

    # Plot the data
    ax.plot(df.index, df['value'], color='red', linewidth=1)

    # Set title and labels
    ax.set_title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019")
    ax.set_xlabel("Date")
    ax.set_ylabel("Page Views")

    # Improve tick formatting
    ax.tick_params(axis='x', rotation=30)

    return fig  # Returning the figure for further use

draw_line_plot()
